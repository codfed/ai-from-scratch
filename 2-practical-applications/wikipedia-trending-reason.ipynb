# %% [markdown]
# ## ✨Why is it trending on Wikipedia?✨
#
# Track the world's curiosities through Wikipedia's featured content endpoint, then summarize the news surrounding it. My favorite side project is https://wiki-chronicle.lovable.app/. I love this daily news digest because it's as far removed from an algorithmic news feed as you can get. You get to see what has climbed to the top of all the rest of the algorithmic feeds.
#
# **This notebook has 4 steps**
# 1. Get most read article list
# 2. Search the news for each article with `serper`
# 3. Use `gpt-5-mini` to summarize each article
# 4. Display the results
#
# ### ⚒️ Resources ⚒️
#
# #### 🔍 Serper
# - 3rd party Google search API with 2500 free queries upon registration
# - https://serper.dev/
#
# #### 🌐 Wikipeda Featured Contact Enpoint
# - Wikimedia Foundation: parent organization of Wikipedia
# - Wikimedia API: poorly documented, yet incredibly useful API with unbelievably generous usage limits
# - https://api.wikimedia.org/wiki/Feed_API/Reference/Featured_content
#
# #### 🖥️ OpenAI
# - gpt-5-mini
# - https://platform.openai.com/

# %%
# %pip install openai python-dotenv requests

# %% [markdown]
# # 🎬 Step 0: initialization 🎬

# %%
"""
Wikipedia Trending Articles Analyzer
Analyzes trending Wikipedia articles and determines why they're popular using AI.
"""

import datetime
import json
import os
from typing import Dict, List, Optional

import requests
from dotenv import load_dotenv
from IPython.display import HTML, display
from openai import OpenAI

# Load environment variables
load_dotenv()

# API Configuration
SERPER_API_KEY = os.environ["SERPER_API_KEY"]
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# Constants
DEFAULT_ARTICLE_COUNT = 5
WIKIPEDIA_USER_AGENT = "WikipediaTrendingAnalyzer/1.0"
SERPER_NEWS_URL = "https://google.serper.dev/news"

# %% [markdown]
# # 🥇 Step 1: fetch most read Wikipedia articles 🥇

# %%
def get_top_articles(date: Optional[datetime.date] = None, n: int = DEFAULT_ARTICLE_COUNT) -> List[Dict]:
    """Fetch top trending Wikipedia articles for a given date.
    
    Args:
        date: Date to fetch articles for (default: today)
        n: Number of articles to return (default: 5)
    
    Returns:
        List of article dictionaries from Wikipedia API
    """
    if date is None:
        date = datetime.date.today()
    
    url = f"https://api.wikimedia.org/feed/v1/wikipedia/en/featured/{date:%Y/%m/%d}"
    headers = {"User-Agent": WIKIPEDIA_USER_AGENT}
    
    try:
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        feed = response.json()
        return feed.get("mostread", {}).get("articles", [])[:n]
    except requests.RequestException as e:
        print(f"Error fetching Wikipedia data: {e}")
        return []
    except ValueError as e:
        print(f"Error parsing Wikipedia response: {e}")
        return []

# Test the function
trending_articles = get_top_articles(datetime.date(2025, 10, 2))
print(f"Found {len(trending_articles)} trending articles")
# Out:
# Found 5 trending articles

# %%
def process_articles(raw_articles: List[Dict]) -> List[Dict]:
    """Process raw Wikipedia articles into a standardized format.
    
    Args:
        raw_articles: List of raw article dictionaries from Wikipedia API
        
    Returns:
        List of processed article dictionaries with standardized fields
    """
    processed_articles = []
    
    for article in raw_articles:
        processed_article = {
            "title": article.get("titles", {}).get("normalized", "Unknown Title"),
            "view_count": article.get("views", 0),
            "link": article.get("content_urls", {}).get("desktop", {}).get("page", ""),
            "thumbnail": article.get("thumbnail", {}).get("source"),
            "raw_news_results": {},
            "trending_reason": ""
        }
        processed_articles.append(processed_article)
    
    return processed_articles

# Process the articles
article_list = process_articles(trending_articles)
print(f"Processed {len(article_list)} articles successfully")

for i, article in enumerate(article_list, 1):
    print(f"{i}. {article['title']} - {article['view_count']:,} views")
# Out:
# Processed 5 articles successfully
# 1. Jane Goodall - 777,022 views
# 2. Government shutdowns in the United States - 589,948 views
# 3. Google Chrome - 412,667 views
# 4. Pete Hegseth - 349,235 views
# 5. Mae Martin - 175,435 views

# %% [markdown]
# # 🗞️ Step 2: fetch related news 🗞️

# %%
def fetch_news_for_article(title: str) -> Dict:
    """Fetch recent news articles related to a Wikipedia article title.
    
    Args:
        title: The Wikipedia article title to search for
        
    Returns:
        Dictionary containing news search results from Serper API
    """
    payload = {
        "q": title,
        "autocorrect": False,
        "tbs": "qdr:w"  # Last week
    }
    
    headers = {
        "X-API-KEY": SERPER_API_KEY,
        "Content-Type": "application/json"
    }
    
    try:
        response = requests.post(
            SERPER_NEWS_URL, 
            headers=headers, 
            json=payload,
            timeout=10
        )
        response.raise_for_status()
        return response.json()
    except requests.RequestException as e:
        print(f"Error fetching news for '{title}': {e}")
        return {"news": []}
    except ValueError as e:
        print(f"Error parsing news response for '{title}': {e}")
        return {"news": []}

# Fetch news for each article
print("Fetching news data for articles...")
for i, article in enumerate(article_list, 1):
    print(f"🐶 Fetching news for article {i}/{len(article_list)}: {article['title']}")
    results = fetch_news_for_article(article["title"])
    article["raw_news_results"] = results
    print(f" ✦ returned {len(results.get('news', []))} articles")

print("News data collection complete!")
# Out:
# Fetching news data for articles...
# 🐶 Fetching news for article 1/5: Jane Goodall
#  ✦ returned 10 articles
# 🐶 Fetching news for article 2/5: Government shutdowns in the United States
#  ✦ returned 10 articles
# 🐶 Fetching news for article 3/5: Google Chrome
#  ✦ returned 10 articles
# 🐶 Fetching news for article 4/5: Pete Hegseth
#  ✦ returned 10 articles
# 🐶 Fetching news for article 5/5: Mae Martin
#  ✦ returned 10 articles
# News data collection complete!

# %%
# Initialize OpenAI client (already imported above)
openai_client = OpenAI(api_key=OPENAI_API_KEY)

def analyze_trending_reason(title: str, news_articles: List[Dict]) -> str:
    """Analyze why a Wikipedia article is trending based on recent news.
    
    Args:
        title: The Wikipedia article title
        news_articles: List of recent news articles related to the title
        
    Returns:
        AI-generated explanation of why the article is trending
    """
    if not news_articles:
        return "No recent news found to explain trending status"
    
    # Create a concise prompt for the AI
    prompt = f"""You are a concise news analysis assistant. If you see the opportunity for whimsy, you take it. 

Analyze the provided news articles to determine why the Wikipedia article "{title}" is receiving attention. 

Provide a brief explanation in no more than 2–3 short sentences. If no clear reason can be identified, output "Unclear why this article is trending". 

Do not start your answer with phrases like "Here is the reason why..." or "The article is trending because...". Avoid words like "spotlight" and "widespread".

Recent news articles:
{json.dumps(news_articles, indent=2)}"""
    
    try:
        response = openai_client.chat.completions.create(
            model="gpt-5-mini",
            messages=[
                {
                    "role": "user",
                    "content": prompt
                }
            ]
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        print(f"Error analyzing trends for '{title}': {e}")
        return "Error occurred during analysis"

# Analyze trending reasons for each article
print("Analyzing trending reasons...")
for i, article in enumerate(article_list, 1):
    title = article["title"]
    news_articles = article["raw_news_results"].get("news", [])
    
    print(f"🔬 Analyzing article {i}/{len(article_list)}: {title}")
    
    trending_reason = analyze_trending_reason(title, news_articles)
    article["trending_reason"] = trending_reason
    
    print(f"📋 Analysis: {trending_reason}")
    print("-" * 50)

print("✅ AI analysis complete!")
# Out:
# Analyzing trending reasons...
# 🔬 Analyzing article 1/5: Jane Goodall
# 📋 Analysis: Major outlets published obituaries and tributes after Dr. Jane Goodall died on October 1, 2025, prompting many people to look up her biography. Readers are visiting Wikipedia to review her life, research, awards and recent interviews.
# --------------------------------------------------
# 🔬 Analyzing article 2/5: Government shutdowns in the United States
# 📋 Analysis: A federal government shutdown that’s now stretched past a week — with IRS furloughs, airport delays and a White House memo on backpay — has pushed people to look up how shutdowns work. Readers are using the Wikipedia page for quick history, legal context and comparisons to past shutdowns.
# --------------------------------------------------
# 🔬 Analyzing article 3/5: Google Chrome
# 📋 Analysis: Reports of multiple security bugs — including an actively exploited zero‑day and published exploit code — have prompted urgent patch coverage and update warnings for Google Chrome. Concurrently, user‑facing changes (the AI Mode address bar) and Android desktop‑mode experiments are generating how‑tos and feature stories, keeping the article in the news.
# --------------------------------------------------
# 🔬 Analyzing article 4/5: Pete Hegseth
# 📋 Analysis: Pete Hegseth, now defense secretary, has provoked heavy coverage after a provocative Quantico speech to senior officers outlining contentious domestic missions and attacking diversity-and-equity programs. Rapid follow-ups — firing a top Navy official and proposing strict grooming and gender-related policies — have generated intense criticism and likely prompted frequent Wikipedia edits.
# --------------------------------------------------
# 🔬 Analyzing article 5/5: Mae Martin
# 📋 Analysis: Coverage of Mae Martin’s new Netflix miniseries Wayward — their role as creator/star and the show’s twisty finale — is driving interest in their Wikipedia page. Media interviews and stories about a possible season 2 plus Martin’s personal inspirations and trans role have amplified searches.
# --------------------------------------------------
# ✅ AI analysis complete!

# %% [markdown]
# # 📰 Step 4: Publish the results 📰

# %%
# Display the articles with thumbnails in a nice list format
from IPython.display import display, HTML

def create_article_html(articles):
    html = """
    <style>
        .article-list {
            font-family: Arial, sans-serif;
            max-width: 800px;
            margin: 20px 0;
        }
        .article-item {
            display: inline-block;
            width: 100%;
            border: 1px solid #ddd;
            border-radius: 8px;
            background: #f8f9fa;
            margin-bottom: 15px;
            padding: 10px;
        }
        .article-thumbnail {
            float: left;
            width: 180px;
            height: 180px;
            object-fit: scale-down;
            border-radius: 6px;
            margin-right: 15px;
        }
        .no-thumbnail {
            float: left;
            width: 180px;
            height: 180px;
            background: #dee2e6;
            border-radius: 6px;
            margin-right: 15px;
            color: #6c757d;
            font-size: 12px;
            line-height: 80px;
            text-align: center;
        }
        .article-content {
            overflow: hidden;
        }
        .article-title {
            font-size: 18px;
            font-weight: 600;
            color: #1a1a1a;
            margin: 0 0 5px 0;
            text-decoration: none;
            display: block;
        }
        .article-title:hover {
            color: #0066cc;
        }
        .article-views {
            color: #666;
            font-size: 14px;
            margin-bottom: 8px;
        }
        .article-reason {
            color: #444;
            font-size: 14px;
            line-height: 1.4;
        }
    </style>

    <div class="article-list">
        <h2>📈 Trending Wikipedia Articles</h2>
    """
    
    for article in articles:
        title = article["title"]
        views = f"{article["view_count"]:,}"
        link = article["link"]
        thumbnail = article.get("thumbnail")
        reason = article.get("trending_reason", "Analysis pending...")
        
        # Handle thumbnail display
        if thumbnail:
            img_html = f'<img src="{thumbnail}" alt="{title}" class="article-thumbnail">'
        else:
            img_html = '<div class="no-thumbnail">No Image</div>'
        
        html += f"""
        <div class="article-item">
            {img_html}
            <div class="article-content">
                <a href="{link}" target="_blank" class="article-title">{title}</a>
                <div class="article-views">👁️ {views} views</div>
                <div class="article-reason">{reason}</div>
            </div>
        </div>
        """
    
    html += "</div>"
    return html

# Display the articles
article_html = create_article_html(article_list)
display(HTML(article_html))
# Out:
#     <style>
#         .article-list {
#             font-family: Arial, sans-serif;
#             max-width: 800px;
#             margin: 20px 0;
#         }
#         .article-item {
#             display: inline-block;
#             width: 100%;
#             border: 1px solid #ddd;
#             border-radius: 8px;
#             background: #f8f9fa;
#             margin-bottom: 15px;
#             padding: 10px;
#         }
#         .article-thumbnail {
#             float: left;
#             width: 180px;
#             height: 180px;
#             object-fit: scale-down;
#             border-radius: 6px;
#             margin-right: 15px;
#         }
#         .no-thumbnail {
#             float: left;
#             width: 180px;
#             height: 180px;
#             background: #dee2e6;
#             border-radius: 6px;
#             margin-right: 15px;
#             color: #6c757d;
#             font-size: 12px;
#             line-height: 80px;
#             text-align: center;
#         }
#         .article-content {
#             overflow: hidden;
#         }
#         .article-title {
#             font-size: 18px;
#             font-weight: 600;
#             color: #1a1a1a;
#             margin: 0 0 5px 0;
#             text-decoration: none;
#             display: block;
#         }
#         .article-title:hover {
#             color: #0066cc;
#         }
#         .article-views {
#             color: #666;
#             font-size: 14px;
#             margin-bottom: 8px;
#         }
#         .article-reason {
#             color: #444;
#             font-size: 14px;
#             line-height: 1.4;
#         }
#     </style>
#
#     <div class="article-list">
#         <h2>📈 Trending Wikipedia Articles</h2>
#
#         <div class="article-item">
#             <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/9/98/Deputy_Secretary_Higginbottom_Poses_for_a_Photo_With_Dr._Jane_Goodall_and_the_State_Department%27s_Global_Health_Diplomacy_Director_Jordan_in_Washington_%2822365513310%29_%282%29_%28cropped_2%29.jpg/330px-thumbnail.jpg" alt="Jane Goodall" class="article-thumbnail">
#             <div class="article-content">
#                 <a href="https://en.wikipedia.org/wiki/Jane_Goodall" target="_blank" class="article-title">Jane Goodall</a>
#                 <div class="article-views">👁️ 777,022 views</div>
#                 <div class="article-reason">Major outlets published obituaries and tributes after Dr. Jane Goodall died on October 1, 2025, prompting many people to look up her biography. Readers are visiting Wikipedia to review her life, research, awards and recent interviews.</div>
#             </div>
#         </div>
#
#         <div class="article-item">
#             <div class="no-thumbnail">No Image</div>
#             <div class="article-content">
#                 <a href="https://en.wikipedia.org/wiki/Government_shutdowns_in_the_United_States" target="_blank" class="article-title">Government shutdowns in the United States</a>
#                 <div class="article-views">👁️ 589,948 views</div>
#                 <div class="article-reason">A federal government shutdown that’s now stretched past a week — with IRS furloughs, airport delays and a White House memo on backpay — has pushed people to look up how shutdowns work. Readers are using the Wikipedia page for quick history, legal context and comparisons to past shutdowns.</div>
#             </div>
#         </div>
#
#         <div class="article-item">
#             <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/e1/Google_Chrome_icon_%28February_2022%29.svg/320px-Google_Chrome_icon_%28February_2022%29.svg.png" alt="Google Chrome" class="article-thumbnail">
#             <div class="article-content">
#                 <a href="https://en.wikipedia.org/wiki/Google_Chrome" target="_blank" class="article-title">Google Chrome</a>
#                 <div class="article-views">👁️ 412,667 views</div>
#                 <div class="article-reason">Reports of multiple security bugs — including an actively exploited zero‑day and published exploit code — have prompted urgent patch coverage and update warnings for Google Chrome. Concurrently, user‑facing changes (the AI Mode address bar) and Android desktop‑mode experiments are generating how‑tos and feature stories, keeping the article in the news.</div>
#             </div>
#         </div>
#
#         <div class="article-item">
#             <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Pete_Hegseth_Official_Portrait.jpg/330px-Pete_Hegseth_Official_Portrait.jpg" alt="Pete Hegseth" class="article-thumbnail">
#             <div class="article-content">
#                 <a href="https://en.wikipedia.org/wiki/Pete_Hegseth" target="_blank" class="article-title">Pete Hegseth</a>
#                 <div class="article-views">👁️ 349,235 views</div>
#                 <div class="article-reason">Pete Hegseth, now defense secretary, has provoked heavy coverage after a provocative Quantico speech to senior officers outlining contentious domestic missions and attacking diversity-and-equity programs. Rapid follow-ups — firing a top Navy official and proposing strict grooming and gender-related policies — have generated intense criticism and likely prompted frequent Wikipedia edits.</div>
#             </div>
#         </div>
#
#         <div class="article-item">
#             <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c8/Mae-Martin-20150724-008.jpg/330px-Mae-Martin-20150724-008.jpg" alt="Mae Martin" class="article-thumbnail">
#             <div class="article-content">
#                 <a href="https://en.wikipedia.org/wiki/Mae_Martin" target="_blank" class="article-title">Mae Martin</a>
#                 <div class="article-views">👁️ 175,435 views</div>
#                 <div class="article-reason">Coverage of Mae Martin’s new Netflix miniseries Wayward — their role as creator/star and the show’s twisty finale — is driving interest in their Wikipedia page. Media interviews and stories about a possible season 2 plus Martin’s personal inspirations and trans role have amplified searches.</div>
#             </div>
#         </div>
#         </div>
